# %%
import kor
import spacy
import pandas as pd
import en_core_sci_md
from langchain.llms import OpenAI
import numpy as np
import os


#Define the OpenAI API key
aiKey = "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"

#Use langchain openai model
llm = OpenAI(openai_api_key=aiKey, model="text-davinci-003", temperature=0.1) # type: ignore
nlp = spacy.load("en_core_sci_md")

#Use NLP Spacy pipelines to takenise patient data from the fifth column in the dataframe

# %%
import csv
from kor import create_extraction_chain
import pandas as pd
from negspacy import Negex


csvPath = r"C:\Users\jreno\Documents\Projects\Mycoach Health\NOTEEVENTS\NOTEEVENTS.csv"

#Display the data as a pandas dataframe and then use scispacy model to perform nlp, concurrent read-csv()
chunksize = 10**6
chunks = []
for chunk in pd.read_csv(csvPath, chunksize=chunksize, low_memory=False):
    chunks.append(chunk)

nlp.add_pipe(negex)
    
#Create the extraction chain
for chunk in chunks:
    texts = chunk['TEXT'].tolist()
    textProc = nlp

#Create a dictionary of the entities and their counts
entDict = {}

for ent in textProc.ents:
    if ent.label_ in entDict:
        entDict[ent.label_] += 1
    else:
        entDict[ent.label_] = 1
# Out:
# C:\Users\jreno\AppData\Local\Temp\ipykernel_10120\2300761528.py:6: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csvPath)
#    ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     174       22532  167853.0  2151-08-04       NaN       NaN
# 1     175       13702  107527.0  2118-06-14       NaN       NaN
# 2     176       13702  167118.0  2119-05-25       NaN       NaN
# 3     177       13702  196489.0  2124-08-18       NaN       NaN
# 4     178       26880  135453.0  2162-03-25       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# 4  Discharge summary      Report   NaN      NaN
#
#                                                 TEXT
# 0  Admission Date:  [**2151-7-16**]       Dischar...
# 1  Admission Date:  [**2118-6-2**]       Discharg...
# 2  Admission Date:  [**2119-5-4**]              D...
# 3  Admission Date:  [**2124-7-21**]              ...
# 4  Admission Date:  [**2162-3-3**]              D...

# %%
import pydantic
from pydantic import Field, BaseModel
from typing import Optional
from kor import Object, Text, Number, create_extraction_chain

#Format below given clinicalAbbr as key value pairs between abbr and description
abbr = { "CSF": "cerebrospinal fluid", 
                "CSU": "catheter stream urine sample",
                "CT scan": "computerised tomography scan",
                "CVP": "central venous pressure", 
                "CXR": "chest X-ray",
                "DNACPR": "do not attempt cardiopulmonary resuscitation",
                "DNAR": "do not attempt resuscitation",
                "DNR": "do not resuscitate", "Dr": "doctor",
                "DVT": "deep vein thrombosis",
                "Dx": "diagnosis",
                "ECG": "electrocardiogram", 
                "ED": "emergency department"
            }

class patient(pydantic.BaseModel):
    patientName: str = Field(
        description="The name of the patient, First Name and Last Name concatenated, maybe given as an ID rather than a name",
        examples = "[**First Name (NamePattern)**]"
    )
    diagnosisData: str = Field(
        description="The summary of the diagnosis of the patient or the final diagnosis of the patient",
    )
    time : Optional[str] = Field(
        description="The time of the diagnosis of the patient",
    )
    clinicalAbbr : Optional[str] = Field(
        description="The clinical abbreviations present in the diagnosis of the patient",
        #Write an example for the same including a clinical abbreviation for the model to detect
        examples = abbr
    )
    medsData : Optional[str] = Field(
        description="The medications of the patient prescribed or administered to the patient, might have abbreviations",
        examples = ["Paracetamol 75mcg p.o." , "Aspirin 81mg p.i. q.d."]
    )
    dischargeData : Optional[str] = Field(
        description="The summary of the discharge of the patient, including the medical status of the patient",
        example= "The patient was able to oxygenate on room air at 93% at the time of discharge."
    )
    medicalScans : Optional[list] = Field(
        description="The summary of the medical scans of the patient, including but not limited to CT Scans, MRIs and X-Ray Scans",
        example = [""]
    )
    
    
#Extension to map composition of heirarchies in daignosis    
class patientHistory(BaseModel):
    patientName

# %%
chain = create_extraction_chain(
    llm,
    schema,
    encoder_or_encoder_class="csv",
    validator=extractionValidator,
    input_formatter = "triple_quotes",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 from kor import create_extraction_chain
#       3 csvPath = r"C:\Users\jreno\Documents\Projects\Mycoach Health\NOTEEVENTS.csv"
#       4 chain = create_extraction_chain(
# ----> 5     llm,
#       6     schema,
#       7     encoder_or_encoder_class="csv",
#       8     validator=extractionValidator,
#       9     input_formatter = "triple_quotes",
#      10 )
#      12 #Import the csv from the above given path and then sort it into
#
# NameError: name 'llm' is not defined

# %%
import pytesseract
from PIL import Image

# Set the directory path where your images are stored
directory = r'img_path'


# Loop through the images in the directory
for filename in os.listdir(directory):
    if filename.endswith('.jpg'):
        image_path = os.path.join(directory, filename)

        # Open the image using PIL
        image = Image.open(image_path)

        # Preprocess the image (example: resizing)
        image = image.resize((1280, 760))  # Adjust the dimensions as needed

        # Perform OCR using Pytesseract with modified parameters
        extracted_text = pytesseract.image_to_string(image, lang='eng', config='--psm 6 --oem 1')

        # Print the extracted text
        print(f"Extracted text from {filename}:")
        print(extracted_text)
        print('-' * 20)
